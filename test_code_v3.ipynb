# %% [markdown]
# <a href="https://colab.research.google.com/github/zero0526/A-Curated-List-of-ML-System-Design-Case-Studies/blob/main/test_code_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zero0526/visual.git
# %cd visual
# !git checkout improve
# Out:
# Cloning into 'visual'...
# remote: Enumerating objects: 1940, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 1940 (delta 14), reused 23 (delta 12), pack-reused 1905 (from 1)
# Receiving objects: 100% (1940/1940), 112.69 MiB | 40.70 MiB/s, done.
# Resolving deltas: 100% (1250/1250), done.
# /content/visual
# Already on 'improve'
# Your branch is up to date with 'origin/improve'.

# %%
import os
import sys

repo_name = 'visual'
os.chdir(f'/content/{repo_name}')

sys.path.append(os.getcwd())

print(f"Thư mục hiện tại: {os.getcwd()}")
# Out:
# Thư mục hiện tại: /content/visual

# %%
import sys
import os
from pathlib import Path

# Ensure project root is in path
PROJECT_ROOT = Path(os.getcwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device name: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA available: False

# %%
import os

plot_dir= "/content/visual/data/plots"
if not os.path.exists(plot_dir):
    os.mkdir(plot_dir)

# %%
from matrix_source.trainers.train import Trainer
from matrix_source.trainers.ppo_stategy import PPOStrategy
from matrix_source.trainers.pposcaffold import PPOSCAFFOLDREPStrategy
from matrix_source.trainers.d3qn_strategy import D3QNStrategy
from matrix_source.trainers.d3qn_scaffold_strategy_v2 import D3QNScaffoldStrategy
from matrix_source.configs.configs import cfg

cfg.hyper_neural["NUM_LOWER_AGENTS"]= 40
cfg.norm_upper_rw= 5_000_000_0.0
cfg.norm_lower_rw= 5_000_000_0.0
if __name__ == '__main__':
    strategy = D3QNScaffoldStrategy()
    trainer = Trainer(strategy=strategy)
    trainer.train()
# Out:
# [D3QNScaffoldStrategy] Initialized 5 SCAFFOLD clusters.
# Training:   0%|          | 0/3000 [00:00<?, ?it/s]/content/visual/matrix_source/trainers/d3qn_scaffold_strategy_v2.py:117: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   a_ids = torch.tensor(batch_actions, device=trainer.device)
# EP    0 | Rew: -92901005312.00 | Delay:   0.11 | Energy:  8579.95 | QoS: 74.08% | Comp: 73.31% | OK: 2761 | FAIL:  966
# INFO:MetricsAggregator:EP    0 | Rew: -92901005312.00 | Delay:   0.11 | Energy:  8579.95 | QoS: 74.08% | Comp: 73.31% | OK: 2761 | FAIL:  966
#  --- Fail Reason Breakdown ---
# INFO:MetricsAggregator: --- Fail Reason Breakdown ---
#   Deadline exceeded : 0
# INFO:MetricsAggregator:  Deadline exceeded : 0
#   Hardware (f_max)  : 431
# INFO:MetricsAggregator:  Hardware (f_max)  : 431
#   Queue full        : 0
# ...
